# %% [markdown]
# [뤼튼](https://wrtn.ai)
# - GPT-4 기반
#
# [레오나르도](https://leonardo.ai)
# - Stable Diffusion이 공짜긴 한데 퀄리티가 좀 그럼
# - Bing Image (DALLE-3) 쓰는 거 추천
#
# [소스](https://github.com/davecom/ClassicComputerScienceProblemsInPython)
# - 과제들은 여기서
#
# [ChatPDF](https://chatpdf.com)
# - 논문 분석할 때 대박

# %% [markdown]
# - OpenAI - ChatGPT를 만든 회사
# - Generative AI - 생성형 AI. 문장 생성도 그렇고 이미지 생성도 그렇고
# - AI models - 아주 큰 함수라고 생각해보자고
# - LLM: Large Language Model - 거대 언어 모델
# - Prompts - GPT에 던지는 메시지들
#   - Promt Engineering - 원하는 결과를 얻기 위한 정확한 GPT 프롬프트를 만드는 방법에 대한 연구

# %% [markdown]
# ## 토큰?
# | input | word | tokens | break-down
# | --- | --- | --- | --- |
# | pre-school study | `[2]` | `[4]` | `pre` `-` `school` `study` |
# | 나는 훈민정음을 창제한 세종대왕을 존경한다. | `[5]` | `[12]`<br>(ChatGPT: `[28]`) | (ChatGPT: `나` `는` ` �` `�` `�` `�` `�` `정` `음` `을`<br>` �` `�` `제` `한` ` �` `�` `�` `�` `�` `대` `�` `�` `을`<br>` �` `�` `�` `경` `한다` `.`) |
#
# GPT 모델의 계산 단위로, 영어 기준으로 어근 단위에 해당한다.
# - OpenAI에 따르면, Multibyte Unicode 문자열의 경우 둘 이상의 토큰으로 쪼개지는 경우가 있다.
