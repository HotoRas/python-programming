# %%
n = int(input('프롬프트 갯수? '))

promptList=[]
for _ in range(n):
    prompt=input('프롬프트 내용?')
    promptList.append(prompt)


print('##'.join(promptList))

# %%
n = int(input('질문 갯수? ')) 

itemList=[]
qList=[]

for _ in range(n):
    item = input('질문할 대상? ')
    itemList.append(item)
    q = input(f'{item}에게 질문할 내용? ')
    qList.append(q)

print('\n')
print(
    "\""+\
    f"itemList = {itemList}\n"+\
    f"qList = {qList}\n"+\
    "[ 당신은 <item>이야. <question>에 대해 설명해줘. for (item, question) in zip(<itemList>, <qList>)]"+"\""
    )

# %%
n = int(input('아이템 갯수? ')) 
itemList=[]

for _ in range(n):
    item = input('질문할 대상? ')
    itemList.append(item)
    
print('\n')
print("\""+\
      f"itemList={itemList}\n"+\
      '''
      ['<item>이 뭐야?'##
       '<item>은 뭐라고 할 수 있어?'##
       '<item>에 대해 누군가에게 설명한다면 뭐라고 할 거야?' for item in <itemList>]'''+"\""   
      )

# %%
m=int(input('item 갯수? '))
n=int(input('audience 갯수? '))

itemList=[]
audienceList=[]

for _ in range(m):
    item = input('관심 item? ')
    itemList.append(item)
    
for _ in range(n):
    audience = input('대상 audience? ')
    audienceList.append(audience)
    
print('\n')
print("\""+\
      f"itemList={itemList}\n"+\
      f"audienceList={audienceList}\n"+\
      '''
      [너는 인공지능 <item>을 <audience>에게 소개해주는 강사야.
      뭐라고 소개해 줄래? for item in <itemList> for audience in <audienceList>]'''+"\""   
      )

# %%
from collections import Counter

print((Counter([sum([int(i) for i in str(j)]) for j in list(range(10,100))])))
