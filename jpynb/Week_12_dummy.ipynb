# %% [markdown]
# ```py
# # src:
# n = int(input('아이템 갯수? '))
# itemList=[]
#
# for _ in range(n):
#     item = input('질문할 대상? ')
#     itemList.append(item)
#
# print('\n')
# print("\""+\
#       f"itemList={itemList}\n"+\
#       '''
#       ['<item>이 뭐야?'##
#        '<item>은 뭐라고 할 수 있어?'##
#        '<item>에 대해 누군가에게 설명한다면 뭐라고 할 거야?' for item in <itemList>]'''+"\""
#       )
# ```

# %%
n = int(input('아이템 갯수? ')) 
itemList=[]

for _ in range(n):
    item = input('질문할 대상? ')
    itemList.append(item)
    
print('\n')

print('"'+f"itemList={itemList}\n"+
      '''
["<item>을 한글로 번역해줘" for item in <itemList>]'''
      +'"'
     )
# Out:
# 아이템 갯수? 2
# 질문할 대상? Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many golf balls did he have at the end of wednesday?
# 질문할 대상? Olivia has $23. She bought five bagels for $3 each. How much money does she have left?
#
#
# "itemList=['Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many golf balls did he have at the end of wednesday?', 'Olivia has $23. She bought five bagels for $3 each. How much money does she have left?']
#
# ["<item>을 한글로 번역해줘" for item in <itemList>]"

# %%
n = int(input('아이템 갯수? '))
itemList = []

for _ in range(n):
    item = input('질문? ')
    itemList.append(item)

print('\n')

print('"'+f"itemList={itemList}\n"+'''
["다음 문장을 해결하기 위한 파이썬 코드를 생성해줘:
<item>" for item in <itemList>]''' + '"')
# Out:
# 아이템 갯수? 2
# 질문? Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many golf balls did he have at the end of wednesday?
# 질문? Olivia has $23. She bought five bagels for $3 each. How much money does she have left?
#
#
# "itemList=['Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many golf balls did he have at the end of wednesday?', 'Olivia has $23. She bought five bagels for $3 each. How much money does she have left?']
#
# ["다음 문장을 해결하기 위한 파이썬 코드를 생성해줘:
# <item>" for item in <itemList>]"

# %%
n = int(input('아이템 갯수? '))
itemList = []

for _ in range(n):
    item = input('질문? ')
    itemList.append(item)
    
print('\n')

print('"'+f"itemList={itemList}\n"+'''
["다음 문장을 단계적으로 해결해줘:
<item>" for item in <itemList>]''' + '"')
# Out:
# 아이템 갯수? 2
# 질문? Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many golf balls did he have at the end of wednesday?
# 질문? Olivia has $23. She bought five bagels for $3 each. How much money does she have left?
#
#
# "itemList=['Michael had 58 golf balls. On tuesday, he lost 23 golf balls. On wednesday, he lost 2 more. How many golf balls did he have at the end of wednesday?', 'Olivia has $23. She bought five bagels for $3 each. How much money does she have left?']
#
# ["다음 문장을 단계적으로 해결해줘:
# <item>" for item in <itemList>]"

# %%
print('다수의 템플릿을 생성하는 템플릿입니다. 한국어만 지원하고 있습니다.')
templateCount = int(input('템플릿의 개수를 설정해주세요: '))
templateList = []

for _ in range(n):
    master = input('무엇의 권위자로 설정하시겠습니까? ')
    
    ufTest = input('울프레임 플러그인을 사용할까요? {예: y; 아니오: n} ')
    ufBl = False
    if ufTest.lower() == y:
        ufBl = True
    
    stepTest = input('단계적으로 풀이할까요? {예: y; 아니오: n} ')
    stepBl = False
    if stepTest.lower() == y:
        stepBl = True
    
    difficulty = input('난이도는 어떻게 할까요?\n\t'+
                       '예시: 8살 아이도 이해하기 쉽게 비유적으로\n\t'+
                       '예시: IT 전문가가 설명하듯이\n입력: ')
    # use strict
    temperature = 0.01
    top-p = 0.01
    tone = "friendly"
