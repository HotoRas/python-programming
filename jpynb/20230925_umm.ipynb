# %%
class SmartPhone:
    def __init__(self,brand,color):
        self.brand=brand
        self.color=color
        
    def set_owner(self,owner):
        self.owner=owner
    
    def call(self,number):
        print(f'색상이 {self.color}인 {self.brand} 스마트폰이 {number}로 전화 중')

# %%
a=SmartPhone('Apple','Black')
a.call('010-1234-5678')
# Out:
# 색상이 Black인 Apple 스마트폰이 010-1234-5678로 전화 중

# %%
s=SmartPhone('Samsung','white')
s.call('010-1111-2222')
# Out:
# 색상이 white인 Samsung 스마트폰이 010-1111-2222로 전화 중

# %%
c=SmartPhone('Xiaomi','yellow')
c.call('010-8888-8888')
# Out:
# 색상이 yellow인 Xiaomi 스마트폰이 010-8888-8888로 전화 중

# %%
class Phone(SmartPhone):
